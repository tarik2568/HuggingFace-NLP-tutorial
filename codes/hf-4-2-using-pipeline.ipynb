# %%
from transformers import pipeline
camembert_fill_mask = pipeline("fill-mask", model = "camembert-base")

# %%
result = camembert_fill_mask("Le camembert est <mask>: :)")
result
# Out:
# [{'score': 0.15368632972240448,
#   'token': 1415,
#   'token_str': 'prêt',
#   'sequence': 'Le camembert est prêt : :)'},
#  {'score': 0.1017332524061203,
#   'token': 1059,
#   'token_str': 'disponible',
#   'sequence': 'Le camembert est disponible : :)'},
#  {'score': 0.0957741066813469,
#   'token': 7200,
#   'token_str': 'délicieux',
#   'sequence': 'Le camembert est délicieux : :)'},
#  {'score': 0.05266101285815239,
#   'token': 2311,
#   'token_str': 'arrivé',
#   'sequence': 'Le camembert est arrivé : :)'},
#  {'score': 0.040779292583465576,
#   'token': 28726,
#   'token_str': 'introuvable',
#   'sequence': 'Le camembert est introuvable : :)'}]

# %%
from transformers import CamembertTokenizer, CamembertForMaskedLM

# %%
tokenizer = CamembertTokenizer.from_pretrained("camembert-base")
model = CamembertForMaskedLM.from_pretrained("camembert-base")

# %%
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
sa_pipeline = pipeline('sentiment-analysis', model = model_name, tokenizer= model_name)

# %%
text1 = "the weather is too hot. I really hate it"
result1 = pipeline(text1)
print(f"Text 1: {text1}")
print(f"Sentiment: {result1[0]['label']} (Confidence: {result1[0]['score']:.2f})")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 text1 = "the weather is too hot. I really hate it"                                           │
# │ ❱ 2 result1 = pipeline(text1)                                                                    │
# │   3 print(f"Text 1: {text1}")                                                                    │
# │   4 print(f"Sentiment: {result1[0]['label']} (Confidence: {result1[0]['score']:.2f})")           │
# │   5                                                                                              │
# │                                                                                                  │
# ...
