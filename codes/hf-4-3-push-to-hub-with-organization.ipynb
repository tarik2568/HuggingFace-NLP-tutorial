# %%
import huggingface_hub
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, TrainingArguments, Trainer
import numpy as np
from huggingface_hub import notebook_login, HfApi, HfFolder,Repository, create_repo

# %%
hf_token = "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"

# %%
huggingface_hub.login(token=hf_token, add_to_git_credential=True)
# Out:
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
model_checkpoint = "csebuetnlp/mT5_multilingual_XLSum"

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# ...
# /opt/conda/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:454: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
tokenizer.push_to_hub("csebuetnlp_mT5_multilingual_XLSum", organization="mitra-et-al", use_auth_token=hf_token, private = True)
# Out:
# CommitInfo(commit_url='https://huggingface.co/mitra-et-al/csebuetnlp_mT5_multilingual_XLSum/commit/ef119f3c9d70d9ead2bfc74894a485d2a4e36d9e', commit_message='Upload tokenizer', commit_description='', oid='ef119f3c9d70d9ead2bfc74894a485d2a4e36d9e', pr_url=None, pr_revision=None, pr_num=None)

# %%
api = HfApi()

# %%
#api.delete_repo("mitra-et-al/dummy-model")

# %%
# !huggingface-cli logout
# Out:
# Successfully logged out.

# %%
# !huggingface-cli login --token $'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'
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !huggingface-cli whoami
# Out:
# tamiti1610001
# orgs:  mitra-et-al

# %%
# !huggingface-cli logout
# Out:
# Successfully logged out.
