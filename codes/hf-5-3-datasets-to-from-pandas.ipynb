# %%
from datasets import load_dataset
dataset = load_dataset("swiss_judgment_prediction","all_languages",split = "train")

# %%
dataset
# Out:
# Dataset({
#     features: ['id', 'year', 'text', 'label', 'language', 'region', 'canton', 'legal area'],
#     num_rows: 59709
# })

# %%
#dataset[0]

# %%
dataset.set_format("pandas")
dataset
# Out:
# Dataset({
#     features: ['id', 'year', 'text', 'label', 'language', 'region', 'canton', 'legal area'],
#     num_rows: 59709
# })

# %%
dataset[0]
# Out:
#    id  year                                               text  label  \
# 0   2  2000  A.- Der 1955 geborene V._ war seit 1. Septembe...      0
#
#   language  region canton     legal area
# 0       de  Zürich     zh  insurance law

# %%
#dataset.head()

# %%
df = dataset.to_pandas()
df.head()
# Out:
#    id  year                                               text  label  \
# 0   2  2000  A.- Der 1955 geborene V._ war seit 1. Septembe...      0
# 1   3  2000  Ansprüche nach OHG, hat sich ergeben: A.- X._ ...      1
# 2   4  2000  Art. 4 aBV (Strafverfahren wegen falschen Zeug...      0
# 3   5  2000  Art. 5 Ziff. 1 EMRK (Haftentlassung), hat sich...      1
# 4   6  2000  Mietvertrag, hat sich ergeben: A.- Die CT Cond...      0
#
#   language                    region canton     legal area
# 0       de                    Zürich     zh  insurance law
# 1       de       Central Switzerland     lu     public law
# 2       de  Northwestern Switzerland     ag     public law
# 3       de                       n/a    n/a     public law
# 4       de                       n/a    n/a      civil law

# %%
dataset.reset_format()
dataset
# Out:
# Dataset({
#     features: ['id', 'year', 'text', 'label', 'language', 'region', 'canton', 'legal area'],
#     num_rows: 59709
# })

# %%
df
# Out:
#          id  year                                               text  label  \
# 0         2  2000  A.- Der 1955 geborene V._ war seit 1. Septembe...      0
# 1         3  2000  Ansprüche nach OHG, hat sich ergeben: A.- X._ ...      1
# 2         4  2000  Art. 4 aBV (Strafverfahren wegen falschen Zeug...      0
# 3         5  2000  Art. 5 Ziff. 1 EMRK (Haftentlassung), hat sich...      1
# 4         6  2000  Mietvertrag, hat sich ergeben: A.- Die CT Cond...      0
# ...     ...   ...                                                ...    ...
# 59704  4053  2014  Fatti: A. Entrata in Svizzera il 15 aprile 200...      0
# 59705  4055  2014  Fatti: A. Con sentenza del 12 febbraio 2008 la...      0
# 59706  4056  2014  Fatti: A. A._, nato nel 1946, ha conseguito la...      1
# 59707  4057  2014  Fatti: A. L'8 ottobre 2008 B._ ha promosso una...      0
# 59708  4060  2014  Fatti: A. A.a. In data 4 marzo 2014 la Confede...      0
#
# ...

# %%
train_df = dataset[:]
#train_df

# %%
frequencies = (
    df["language"]
    .value_counts()
    .to_frame()
    .reset_index()
    .rename(columns={"year": "years", "language": "languages"})
)
frequencies.head()
# Out:
#   index  languages
# 0    de      35458
# 1    fr      21179
# 2    it       3072

# %%
from datasets import Dataset

freq_dataset = Dataset.from_pandas(frequencies)
freq_dataset
# Out:
# Dataset({
#     features: ['index', 'languages'],
#     num_rows: 3
# })

# %%
dataset
# Out:
# Dataset({
#     features: ['id', 'year', 'text', 'label', 'language', 'region', 'canton', 'legal area'],
#     num_rows: 59709
# })

# %%
temp_dataset_1  = dataset.train_test_split(train_size=0.8, seed=42)
dataset = temp_dataset_1 
temp_dataset_1 = dataset["test"].train_test_split(train_size=0.5, seed=42)
dataset["validation"] = temp_dataset_1["train"]
dataset["test"] = temp_dataset_1["test"]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'year', 'text', 'label', 'language', 'region', 'canton', 'legal area'],
#         num_rows: 47767
#     })
#     test: Dataset({
#         features: ['id', 'year', 'text', 'label', 'language', 'region', 'canton', 'legal area'],
#         num_rows: 5971
#     })
#     validation: Dataset({
#         features: ['id', 'year', 'text', 'label', 'language', 'region', 'canton', 'legal area'],
#         num_rows: 5971
#     })
# })

# %%
dataset.save_to_disk("drug-reviews")
# Out:
# ...
# Flattening the indices:   0%|          | 0/6 [00:00<?, ?ba/s]

# %%
df.to_csv("swiss_judgment_prediction")

# %%
raw_datasets = load_dataset("allocine")
raw_datasets.cache_files
